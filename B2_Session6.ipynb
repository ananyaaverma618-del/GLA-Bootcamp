# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyaaverma618-del/GLA-Bootcamp/blob/main/B2_Session6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Machine learning improves by measuring error and correcting itself step by step

# %%
#feature
#label
#prediction problem
#conclusion from the visible data

# %%
#classification- it mean are classifying an object
#regression- to predict a continuous problem

# %%
#face unlock
#predicting land prices
#google photos use what to define faces
#weather forecast


#classification
#
#student results--
JEE MAINS

#feature
percentile
score
rank
category
study hours per day
no of questions attempted
shifts
no students attempted
difficulty level of shifts
